# %%
def get_canadian_companies():
    url = "https://en.wikipedia.org/wiki/List_of_companies_of_Canada"
    companies = pd.read_html(url)[1]  # Get just table 1
    # Clean up the column names (remove multi-index)
    companies.columns = companies.columns.get_level_values(0)
    # Keep only the columns we need
    companies = companies[['Name', 'Industry', 'Sector', 'Notes', 'Headquarters']].copy()
    return companies

# Get the data
companies_df = get_canadian_companies()
companies_df.head()
# Out:
#                            Name           Industry                     Sector  \
# 0               1-800-GOT-JUNK?        Industrials  Waste & disposal services
# 1                   Norda Stelo        Industrials   Construction & Materials
# 2  3Way International Logistics        Industrials  Business support services
# 3                 A Buck or Two  Consumer services        Specialty retailers
# 4                           A&W  Consumer services         Restaurants & bars
#
#                  Notes     Headquarters
# 0         Junk removal        Vancouver
# 1  Integrated projects      Quebec City
# 2   Freight forwarding      Mississauga
# 3               Retail          Vaughan
# 4      Fast food chain  North Vancouver

# %%
from pydantic import BaseModel
from typing import List
from openai import OpenAI
import os

class CompanyVariants(BaseModel):
    original_name: str
    positive_variants: List[str]
    negative_variants: List[str]

# %%
from pydantic import BaseModel
from typing import List
from openai import OpenAI
import os
import pandas as pd
from textdistance import jaro_winkler as jaro_winkler_similarity
from pydantic import BaseModel
from typing import List
from openai import OpenAI
import os

class PositiveVariants(BaseModel):
    positive_variants: List[str]

class NegativeVariants(BaseModel):
    negative_variants: List[str]

class CompanyVariants(BaseModel):
    original_name: str
    positive_variants: List[str]
    negative_variants: List[str]


def generate_company_variants(row: pd.Series) -> CompanyVariants:
    client = OpenAI(api_key=os.environ["OPENAI_API_KEY"])
    
    # First prompt for positive variants
    positive_prompt = f"""
    You are a corporate data verification assistant with knowledge of real corporate filings, stock exchange listings, and official documents (up to your training data cutoff).
    
    Task: Generate up to 5 REAL and VERIFIABLE name variations for this SAME company. Each variation must be an alternate form of the official name found in:
    - Canadian Government filings
    - Canadian Government or historical business registries
    - Official stock exchange listings (e.g., TSX, NYSE)
    - The company's own legal or historical documents
    
    Company Details:
    - Name: '{row['Name']}'
    - Industry: {row['Industry']}
    - Sector: {row['Sector']}
    - Business Type: {row['Notes']}
    
    Requirements for POSITIVE VARIANTS:
    1. All 5 variants must refer to the SAME entity, just documented differently.
    2. Variants should have a LOW string similarity (via Levenshtein or Jaro-Winkler) when compared to the original name (e.g., using abbreviations, historical names, or alternate legal forms).
    3. If you CANNOT confirm an additional variant, return fewer entries and use: "No additional verified variant found" for the remainder.
    4. Do NOT fabricate new or fictional names—only use known, verifiable aliases if they exist.
    
    Return ONLY valid JSON with a single key:
    {{
      "positive_variants": [
         "...",
         "...",
         ...
      ]
    }}
    No extra text or explanation outside the JSON.
    """

    # Second prompt for negative variants
    negative_prompt = f"""
    You are a corporate data verification assistant with knowledge of real Canadian corporate filings, Canadian stock exchange listings, and official documents (up to your training data cutoff).
    
    Task: Generate up to 5 REAL company names that are DISTINCT from '{row['Name']}' but have HIGH Levenshtein or Jaro-Winkler string similarity scores. Despite the similarity, a human can tell they are different entities.
    
    Company Details:
    - Name: '{row['Name']}'
    - Industry: {row['Industry']}
    - Sector: {row['Sector']}
    - Business Type: {row['Notes']}
    
    Requirements for NEGATIVE VARIANTS:
    1. Each must be an actual, verifiably different company (past or present), referenced in credible sources (e.g., official Canadian registries).
    2. Names should share significant overlap in words or structure with '{row['Name']}' to ensure high lexical similarity, but must refer to a separate legal entity.
    3. If you cannot confirm all 5, provide fewer and use "No additional verified variant found" for the rest.
    4. Do NOT fabricate or invent company names.
    
    Return ONLY valid JSON with a single key:
    {{
      "negative_variants": [
         "...",
         "...",
         ...
      ]
    }}
    No extra text or explanation outside the JSON.
    """

    
    pos_response = client.beta.chat.completions.parse(
        model="gpt-4o",
        response_format=PositiveVariants,
        messages=[
            {"role": "system", "content": "You are a helpful assistant that generates real business names as they might appear in different corporate databases and registries."},
            {"role": "user", "content": positive_prompt}
        ]
    )
    
    neg_response = client.beta.chat.completions.parse(
        model="gpt-4o",
        response_format=NegativeVariants,
        messages=[
            {"role": "system", "content": "You are a helpful assistant that generates real business names as they might appear in different corporate databases and registries."},
            {"role": "user", "content": negative_prompt}
        ]
    )
    # Parse the JSON responses
    pos_variants = eval(pos_response.choices[0].message.content)
    neg_variants = eval(neg_response.choices[0].message.content)
    
    # Combine results
    return CompanyVariants(
        original_name=row['Name'],
        positive_variants=pos_variants['positive_variants'],
        negative_variants=neg_variants['negative_variants']
    )

# %%
# Get first company from our dataset
test_company = companies.iloc[0]
print("Testing with company:", test_company['Name'])

try:
    # Generate variants
    variants = generate_company_variants(test_company)
    
    # Print results
    print("\nOriginal Name:", variants.original_name)
    print("\nPositive Variants:")
    for v in variants.positive_variants:
        print(f"- {v}")
    print("\nNegative Variants:")
    for v in variants.negative_variants:
        print(f"- {v}")
        
except Exception as e:
    print(f"Error occurred: {str(e)}")
    print("Response structure:")
    print("Positive response type:", type(pos_response))
    print("Negative response type:", type(neg_response))
# Out:
# Testing with company: 1-800-GOT-JUNK?
#
# Original Name: 1-800-GOT-JUNK?
#
# Positive Variants:
# - The Rubbish Boys Disposal Service Inc.
# - RBDS Junk Removal Inc.
# - RBDS Rubbish Removal
#
# Negative Variants:
# - 1800Junk.com Inc.
# - JUSTJUNK Inc.
# - Junk Ninja
# - Bin There Dump That
# - Green Junk Removal Inc.

# %%
def create_matched_dataset(companies_df: pd.DataFrame, n_samples=None) -> pd.DataFrame:
    """
    For each company:
      - Generate up to 5 positive variants and 5 negative variants.
      - Filter out "No additional verified variant found".
      - From the remaining positive variants, pick the one with the lowest Jaro-Winkler similarity.
      - From the remaining negative variants, pick the one with the highest Jaro-Winkler similarity.
      - Output two rows per company: one labeled '1' (positive) and one labeled '0' (negative).
    """
    
    if n_samples:
        companies_df = companies_df.head(n_samples)
    
    all_pairs = []
    
    for idx, row in companies_df.iterrows():
        try:
            # 1. Generate variants from GPT
            variants = generate_company_variants(row)
            original_name = variants.original_name
            
            # 2. Filter out placeholders from both lists
            pos_variants_filtered = [
                v for v in variants.positive_variants 
                if v.strip().lower() != "no additional verified variant found"
            ]
            neg_variants_filtered = [
                v for v in variants.negative_variants 
                if v.strip().lower() != "no additional verified variant found"
            ]
            
            # If there are no valid positive or negative variants, skip this company
            if not pos_variants_filtered or not neg_variants_filtered:
                print(f"Skipping {original_name}: not enough valid variants.")
                continue
            
            # 3. Compute Jaro-Winkler similarities and pick best positive & negative
            pos_sims = [
                (v, jaro_winkler_similarity(original_name.lower(), v.lower())) 
                for v in pos_variants_filtered
            ]
            # Best positive = the one with the *lowest* JW similarity
            best_positive, best_positive_sim = min(pos_sims, key=lambda x: x[1])
            
            neg_sims = [
                (v, jaro_winkler_similarity(original_name.lower(), v.lower())) 
                for v in neg_variants_filtered
            ]
            # Best negative = the one with the *highest* JW similarity
            best_negative, best_negative_sim = max(neg_sims, key=lambda x: x[1])
            
            # 4. Append results to the dataset
            all_pairs.append({
                'Name_One': original_name,
                'Name_Two': best_positive,
                'Similarity': best_positive_sim,
                'Label': 1  # same entity
            })
            all_pairs.append({
                'Name_One': original_name,
                'Name_Two': best_negative,
                'Similarity': best_negative_sim,
                'Label': 0  # different entity
            })
            
            print(f"Processed company {idx+1}/{len(companies_df)}: {original_name}")
        
        except Exception as e:
            print(f"Error processing {row['Name']}: {str(e)}")
            continue
    
    # 5. Convert to DataFrame
    df = pd.DataFrame(all_pairs)
    print(f"\nCreated dataset with {len(df)} row(s).")
    return df

# Example usage
test_df = create_matched_dataset(companies, n_samples=3)
test_df
# Out:
# Processed company 1/3: 1-800-GOT-JUNK?
# Processed company 2/3: Norda Stelo
# Processed company 3/3: 3Way International Logistics
#
# Created dataset with 6 row(s).
#                        Name_One                                 Name_Two  \
# 0               1-800-GOT-JUNK?  RBDS Rubbish Boys Disposal Service Inc.
# 1               1-800-GOT-JUNK?                         1-800-GOT-DEBRIS
# 2                   Norda Stelo                   Stelo Engineering Ltd.
# 3                   Norda Stelo                        Nordic Steel Ltd.
# 4  3Way International Logistics     Three Way International Incorporated
# 5  3Way International Logistics          Waybest Logistics International
#
#    Similarity  Label
# 0    0.228205      1
# 1    0.858333      0
# 2    0.508658      1
# 3    0.869519      0
# 4    0.662578      1
# 5    0.809282      0

# %%
##############################################
# 3. Generate final dataset for ALL ROWS     #
##############################################
all_rows = []  # will hold final dataset records

for idx, row in companies_df.iterrows():
    # Step A: Generate up to 5 positive & negative variants
    try:
        variants = generate_company_variants(row)
    except Exception as e:
        print(f"Error generating variants for index={idx}, Name='{row['Name']}': {str(e)}")
        continue
    
    # Step B: Filter out placeholders
    pos_filtered = [v for v in variants.positive_variants
                    if v.strip().lower() != "no additional verified variant found"]
    neg_filtered = [v for v in variants.negative_variants
                    if v.strip().lower() != "no additional verified variant found"]
    
    if not pos_filtered or not neg_filtered:
        print(f"Skipping index={idx}, Name='{row['Name']}' - no valid variants.")
        continue
    
    original = variants.original_name  # same as row['Name']

    # Step C: Calculate Jaro-Winkler similarities
    pos_sims = [(v, jaro_winkler_similarity(original.lower(), v.lower())) for v in pos_filtered]
    neg_sims = [(v, jaro_winkler_similarity(original.lower(), v.lower())) for v in neg_filtered]
    
    # Best positive = lowest Jaro-Winkler
    best_positive, pos_sim = min(pos_sims, key=lambda x: x[1])
    # Best negative = highest Jaro-Winkler
    best_negative, neg_sim = max(neg_sims, key=lambda x: x[1])
    
    # Step D: Append 2 new rows (label=1 for positive, label=0 for negative)
    # Include original columns and add CompanyID
    # We'll call them Name_One (original) and Name_Two (variant)
    row_base = {
        "CompanyID": idx,
        "Name": row['Name'],
        "Industry": row['Industry'],
        "Sector": row['Sector'],
        "Notes": row['Notes'],
        "Headquarters": row['Headquarters']
    }
    
    # 1) Positive row
    pos_row = {
        **row_base,
        "Name_One": original,
        "Name_Two": best_positive,
        "Label": 1
    }
    all_rows.append(pos_row)
    
    # 2) Negative row
    neg_row = {
        **row_base,
        "Name_One": original,
        "Name_Two": best_negative,
        "Label": 0
    }
    all_rows.append(neg_row)
    
    print(f"Processed idx={idx}, Name='{row['Name']}' with 2 new rows.")

# Step E: Convert final list to DataFrame
final_df = pd.DataFrame(all_rows)
print(f"\nFinal dataset size: {len(final_df)} rows.")
# Out:
# Processed idx=0, Name='1-800-GOT-JUNK?' with 2 new rows.
# Processed idx=1, Name='Norda Stelo' with 2 new rows.
# Processed idx=2, Name='3Way International Logistics' with 2 new rows.
# Skipping index=3, Name='A Buck or Two' - no valid variants.
# Processed idx=4, Name='A&W' with 2 new rows.
# Processed idx=5, Name='ABS Friction[10]' with 2 new rows.
# Processed idx=6, Name='Access Communications' with 2 new rows.
# Processed idx=7, Name='Ache Records' with 2 new rows.
# Processed idx=8, Name='Addition Elle' with 2 new rows.
# Processed idx=9, Name='Advanced Cyclotron Systems' with 2 new rows.
# Processed idx=10, Name='Affinity Credit Union' with 2 new rows.
# Processed idx=11, Name='AHED' with 2 new rows.
# Processed idx=12, Name='Air Canada' with 2 new rows.
# Processed idx=13, Name='Air Miles' with 2 new rows.
# Skipping index=14, Name='Aldo Group' - no valid variants.
# Processed idx=15, Name='AldrichPears Associates' with 2 new rows.
# Processed idx=16, Name='Algonquin Power & Utilities' with 2 new rows.
# Processed idx=17, Name='Allied Shipbuilders' with 2 new rows.
# Processed idx=18, Name='Alta Newspaper Group' with 2 new rows.
# Processed idx=19, Name='Alterra Power' with 2 new rows.
# Processed idx=20, Name='Angoss' with 2 new rows.
# Skipping index=21, Name='Apotex' - no valid variants.
# Processed idx=22, Name='Appnovation' with 2 new rows.
# Processed idx=23, Name='Arc'teryx' with 2 new rows.
# Processed idx=24, Name='Areva Resources Canada' with 2 new rows.
# Processed idx=25, Name='Aritzia' with 2 new rows.
# Processed idx=26, Name='Army & Navy Stores' with 2 new rows.
# Processed idx=27, Name='Arsenal Pulp Press' with 2 new rows.
# Processed idx=28, Name='ATB Financial' with 2 new rows.
# Processed idx=29, Name='ATI Technologies' with 2 new rows.
# Processed idx=30, Name='Atmosphere Visual Effects' with 2 new rows.
# Processed idx=31, Name='Atwill-Morin' with 2 new rows.
# Processed idx=32, Name='Ballard Power Systems' with 2 new rows.
# Processed idx=33, Name='Banff Lodging Co' with 2 new rows.
# Processed idx=34, Name='Bank of Montreal' with 2 new rows.
# Processed idx=35, Name='Bard Ventures' with 2 new rows.
# Processed idx=36, Name='Barrick Gold' with 2 new rows.
# Processed idx=37, Name='Bausch Health' with 2 new rows.
# Processed idx=38, Name='BBC Kids' with 2 new rows.
# Processed idx=39, Name='BC Hydro' with 2 new rows.
# Processed idx=40, Name='BC Research' with 2 new rows.
# Processed idx=41, Name='Becker's' with 2 new rows.
# Processed idx=42, Name='Bell Canada' with 2 new rows.
# Processed idx=43, Name='Bell MTS' with 2 new rows.
# Processed idx=44, Name='Ben Moss Jewellers' with 2 new rows.
# Processed idx=45, Name='Bennett Environmental' with 2 new rows.
# Processed idx=46, Name='Big Blue Bubble' with 2 new rows.
# Processed idx=47, Name='BigPark' with 2 new rows.
# Skipping index=48, Name='Biovail' - no valid variants.
# Processed idx=49, Name='BioWare' with 2 new rows.
# Processed idx=50, Name='Bison Transport' with 2 new rows.
# Processed idx=51, Name='Black Diamond Cheese' with 2 new rows.
# Processed idx=52, Name='Black Hen Music' with 2 new rows.
# Processed idx=53, Name='Black Press' with 2 new rows.
# Processed idx=54, Name='Blacks Photo Corporation' with 2 new rows.
# Processed idx=55, Name='BlackBerry Limited' with 2 new rows.
# Processed idx=56, Name='Blackburn Radio' with 2 new rows.
# Processed idx=57, Name='Blake, Cassels & Graydon' with 2 new rows.
# Processed idx=58, Name='Bleeding Art Industries' with 2 new rows.
# Processed idx=59, Name='Blenz Coffee' with 2 new rows.
# Processed idx=60, Name='Blue Giant Equipment Corporation' with 2 new rows.
# Skipping index=61, Name='Bluenotes' - no valid variants.
# Skipping index=62, Name='Boeing Canada' - no valid variants.
# Processed idx=63, Name='Bombardier' with 2 new rows.
# Processed idx=64, Name='Bombardier Recreational Products' with 2 new rows.
# Processed idx=65, Name='Book City' with 2 new rows.
# Processed idx=66, Name='Boston Pizza' with 2 new rows.
# Processed idx=67, Name='Boutique La Vie en Rose' with 2 new rows.
# Processed idx=68, Name='Bowring Brothers' with 2 new rows.
# Processed idx=69, Name='Bre-X' with 2 new rows.
# Processed idx=70, Name='Brick Brewing Company' with 2 new rows.
# Processed idx=71, Name='Brightlight Pictures' with 2 new rows.
# Processed idx=72, Name='BrightSide Technologies' with 2 new rows.
# Processed idx=73, Name='Brookfield Corporation' with 2 new rows.
# Skipping index=74, Name='Bruce Power' - no valid variants.
# Processed idx=75, Name='Brunet' with 2 new rows.
# Processed idx=76, Name='Buckley's' with 2 new rows.
# Processed idx=77, Name='Buhler Industries' with 2 new rows.
# Processed idx=78, Name='Bullfrog Power' with 2 new rows.
# Processed idx=79, Name='Cactus Club Cafe' with 2 new rows.
# Processed idx=80, Name='Cadillac Fairview' with 2 new rows.
# Processed idx=81, Name='CAE Inc.' with 2 new rows.
# Processed idx=82, Name='Cafection' with 2 new rows.
# Processed idx=83, Name='Calm Air' with 2 new rows.
# Processed idx=84, Name='Cameco' with 2 new rows.
# Processed idx=85, Name='Canada Bread' with 2 new rows.
# Processed idx=86, Name='Canada Deposit Insurance Corporation' with 2 new rows.
# Processed idx=87, Name='Canada Post' with 2 new rows.
# Processed idx=88, Name='Canada Wide Media' with 2 new rows.
# Skipping index=89, Name='Canadian Bank Note Company' - no valid variants.
# Processed idx=90, Name='Canadian Broadcasting Corporation (CBC)' with 2 new rows.
# Processed idx=91, Name='Canadian Hydro Developers' with 2 new rows.
# Processed idx=92, Name='Canadian Imperial Bank of Commerce (CIBC)' with 2 new rows.
# Processed idx=93, Name='Canadian Light Source' with 2 new rows.
# Processed idx=94, Name='Canadian National Railway' with 2 new rows.
# Processed idx=95, Name='Canadian Natural Resources' with 2 new rows.
# Processed idx=96, Name='Canadian Oil Sands' with 2 new rows.
# Processed idx=97, Name='Canadian Pacific Railway Limited' with 2 new rows.
# Skipping index=98, Name='Canadian Plasma Resources' - no valid variants.
# Processed idx=99, Name='Canadian Steamship Lines' with 2 new rows.
# Processed idx=100, Name='Canadian Tire' with 2 new rows.
# Processed idx=101, Name='Canadian Tire Bank' with 2 new rows.
# Processed idx=102, Name='Canadian Western Bank' with 2 new rows.
# Processed idx=103, Name='Canadian Wheat Board' with 2 new rows.
# Skipping index=104, Name='Canalta Hotels' - no valid variants.
# Processed idx=105, Name='Candente Copper' with 2 new rows.
# Processed idx=106, Name='Cangene Corp.' with 2 new rows.
# Processed idx=107, Name='CanJet' with 2 new rows.
# Processed idx=108, Name='Canpotex' with 2 new rows.
# Processed idx=109, Name='Canucks Sports & Entertainment' with 2 new rows.
# Processed idx=110, Name='Canwest' with 2 new rows.
# Processed idx=111, Name='Capcom Vancouver' with 2 new rows.
# Processed idx=112, Name='Cargill Ltd.' with 2 new rows.
# Processed idx=113, Name='Casavant Frères' with 2 new rows.
# Processed idx=114, Name='Cascades' with 2 new rows.
# Processed idx=115, Name='Catalyst Paper' with 2 new rows.
# Processed idx=116, Name='Cedarlane Laboratories' with 2 new rows.
# Processed idx=117, Name='Celestica' with 2 new rows.
# Processed idx=118, Name='Cellcom Communications' with 2 new rows.
# Processed idx=119, Name='Cenovus Energy' with 2 new rows.
# Processed idx=120, Name='Centra Gas Manitoba Inc.' with 2 new rows.
# Processed idx=121, Name='Central Heat Distribution' with 2 new rows.
# Processed idx=122, Name='Central Mountain Air' with 2 new rows.
# Processed idx=123, Name='CGI Group' with 2 new rows.
# Processed idx=124, Name='Chapters' with 2 new rows.
# Processed idx=125, Name='CHC Helicopter' with 2 new rows.
# Skipping index=126, Name='Choices Market' - no valid variants.
# Processed idx=127, Name='Chrysler Canada' with 2 new rows.
# Processed idx=128, Name='CHUM Limited' with 2 new rows.
# Processed idx=129, Name='Cineplex Entertainment' with 2 new rows.
# Processed idx=130, Name='Cirque du Soleil' with 2 new rows.
# Processed idx=131, Name='CityWest' with 2 new rows.
# Processed idx=132, Name='Coachman Insurance Company' with 2 new rows.
# Processed idx=133, Name='Coast Capital Savings' with 2 new rows.
# Processed idx=134, Name='Coffee Time' with 2 new rows.
# Processed idx=135, Name='Cognos' with 2 new rows.
# Processed idx=136, Name='Colt Canada' with 2 new rows.
# Processed idx=137, Name='Comm100' with 2 new rows.
# Processed idx=138, Name='Conestoga-Rovers & Associates' with 2 new rows.
# Processed idx=139, Name='Conexus Credit Union' with 2 new rows.
# Processed idx=140, Name='Continental Newspapers' with 2 new rows.
# Processed idx=141, Name='Cookie Jar Group' with 2 new rows.
# Skipping index=142, Name='Corby Spirit and Wine' - no valid variants.
# Processed idx=143, Name='Cordiant Capital Inc.' with 2 new rows.
# Processed idx=144, Name='Corel' with 2 new rows.
# Processed idx=145, Name='Corma Inc.' with 2 new rows.
# Skipping index=146, Name='Corus Entertainment' - no valid variants.
# Skipping index=147, Name='Coteau Books' - no valid variants.
# Processed idx=148, Name='Cott' with 2 new rows.
# Processed idx=149, Name='Country Style' with 2 new rows.
# Processed idx=150, Name='Creation Technologies' with 2 new rows.
# Processed idx=151, Name='Crestline Coach' with 2 new rows.
# Processed idx=152, Name='Expedia CruiseShipCenters' with 2 new rows.
# Processed idx=153, Name='CSA Group' with 2 new rows.
# Processed idx=154, Name='CTBC Bank (Canada)' with 2 new rows.
# Processed idx=155, Name='CTV Television Network' with 2 new rows.
# Processed idx=156, Name='Cymax Stores' with 2 new rows.
# Processed idx=157, Name='Cyntech' with 2 new rows.
# Processed idx=158, Name='Dairyland Canada' with 2 new rows.
# Processed idx=159, Name='Daiya' with 2 new rows.
# Skipping index=160, Name='Dare Foods' - no valid variants.
# Processed idx=161, Name='Dart Flipcards' with 2 new rows.
# Processed idx=162, Name='Decor Cabinets' with 2 new rows.
# Processed idx=163, Name='Delta Hotels' with 2 new rows.
# Processed idx=164, Name='Descartes Systems Group' with 2 new rows.
# Processed idx=165, Name='Desjardins Group' with 2 new rows.
# Processed idx=166, Name='DHX Media' with 2 new rows.
# Skipping index=167, Name='Digital Extremes' - no valid variants.
# Processed idx=168, Name='Digitcom' with 2 new rows.
# Processed idx=169, Name='Discovery Air Defence' with 2 new rows.
# Processed idx=170, Name='Discovery Air' with 2 new rows.
# Processed idx=171, Name='Dofasco' with 2 new rows.
# Processed idx=172, Name='Dollarama' with 2 new rows.
# Processed idx=173, Name='Dominion Voting Systems' with 2 new rows.
# Processed idx=174, Name='Domtar' with 2 new rows.
# Processed idx=175, Name='Donner Metals' with 2 new rows.
# Processed idx=176, Name='DreamCatcher Games' with 2 new rows.
# Processed idx=177, Name='D-Wave Systems' with 2 new rows.
# Processed idx=178, Name='Dynamotive Energy Systems' with 2 new rows.
# Processed idx=179, Name='DynaVenture' with 2 new rows.
# Skipping index=180, Name='EA Black Box' - no valid variants.
# Processed idx=181, Name='EA Vancouver' with 2 new rows.
# Skipping index=182, Name='Ebco Industries' - no valid variants.
# Processed idx=183, Name='Electrohome' with 2 new rows.
# Processed idx=184, Name='EllisDon' with 2 new rows.
# Skipping index=185, Name='Emera' - no valid variants.
# Skipping index=186, Name='Enbridge' - no valid variants.
# Processed idx=187, Name='Encana' with 2 new rows.
# Processed idx=188, Name='Engineered Lifting Systems & Equipment' with 2 new rows.
# Processed idx=189, Name='Enwave' with 2 new rows.
# Processed idx=190, Name='Esprida' with 2 new rows.
# Processed idx=191, Name='F&P Manufacturing Inc.' with 2 new rows.
# Processed idx=192, Name='Fairchild Group' with 2 new rows.
# Processed idx=193, Name='Fairchild TV' with 2 new rows.
# Processed idx=194, Name='Fairfax Financial' with 2 new rows.
# Processed idx=195, Name='Fairmont Hotels and Resorts' with 2 new rows.
# Skipping index=196, Name='Falconbridge Ltd.' - no valid variants.
# Processed idx=197, Name='Farmers of North America' with 2 new rows.
# Processed idx=198, Name='Federated Co-operatives' with 2 new rows.
# Processed idx=199, Name='FGL Sports' with 2 new rows.
# Processed idx=200, Name='Fido Solutions' with 2 new rows.
# Processed idx=201, Name='Finning' with 2 new rows.
# Processed idx=202, Name='First Air' with 2 new rows.
# Processed idx=203, Name='First Majestic Silver' with 2 new rows.
# Processed idx=204, Name='First Nations Bank of Canada' with 2 new rows.
# Processed idx=205, Name='First Quantum Minerals' with 2 new rows.
# Skipping index=206, Name='Flickr' - no valid variants.
# Skipping index=207, Name='Force Four Entertainment' - no valid variants.
# Processed idx=208, Name='Ford Motor Company of Canada' with 2 new rows.
# Processed idx=209, Name='Fort Garry Brewing Company' with 2 new rows.
# Processed idx=210, Name='Fortis Inc.' with 2 new rows.
# Processed idx=211, Name='FortisBC' with 2 new rows.
# Processed idx=212, Name='Four Seasons Hotels and Resorts' with 2 new rows.
# Processed idx=213, Name='French Shoes' with 2 new rows.
# Processed idx=214, Name='Freedom Mobile' with 2 new rows.
# Processed idx=215, Name='FreshBooks' with 2 new rows.
# Processed idx=216, Name='Freshslice Pizza' with 2 new rows.
# Skipping index=217, Name='Ganz' - no valid variants.
# Processed idx=218, Name='Garage' with 2 new rows.
# Processed idx=219, Name='General Motors Canada' with 2 new rows.
# Processed idx=220, Name='George Weston Limited' with 2 new rows.
# Processed idx=221, Name='Geosoft' with 2 new rows.
# Processed idx=222, Name='Giant Tiger' with 2 new rows.
# Processed idx=223, Name='Glacier Media' with 2 new rows.
# Processed idx=224, Name='Glentel' with 2 new rows.
# Processed idx=225, Name='Global Mechanic' with 2 new rows.
# Skipping index=226, Name='GlobeScan' - no valid variants.
# Processed idx=227, Name='Gnowit' with 2 new rows.
# Processed idx=228, Name='Goldcorp' with 2 new rows.
# Processed idx=229, Name='GoodLife Fitness' with 2 new rows.
# Processed idx=230, Name='Great Western Brewing Company' with 2 new rows.
# Processed idx=231, Name='Groupe Dynamite' with 2 new rows.
# Processed idx=232, Name='Guardian Biotechnologies' with 2 new rows.
# Skipping index=233, Name='GuestLogix' - no valid variants.
# Processed idx=234, Name='Halogen Software' with 2 new rows.
# Processed idx=235, Name='Harbour Publishing' with 2 new rows.
# Processed idx=236, Name='Harlequin Enterprises' with 2 new rows.
# Processed idx=237, Name='Harry Rosen Inc.' with 2 new rows.
# Skipping index=238, Name='Hart Stores' - no valid variants.
# Processed idx=239, Name='Harvey's' with 2 new rows.
# Processed idx=240, Name='Hatch Ltd' with 2 new rows.
# Processed idx=241, Name='Hathor Exploration' with 2 new rows.
# Processed idx=242, Name='Haywire Winery' with 2 new rows.
# Processed idx=243, Name='Hellbent Games' with 2 new rows.
# Processed idx=244, Name='HelpSeeker Technologies' with 2 new rows.
# Processed idx=245, Name='Héroux-Devtek' with 2 new rows.
# Processed idx=246, Name='Hidden Valley Highlands' with 2 new rows.
# Processed idx=247, Name='Home Hardware' with 2 new rows.
# Processed idx=248, Name='Honda Canada Inc.' with 2 new rows.
# Processed idx=249, Name='HSBC Bank Canada' with 2 new rows.
# Processed idx=250, Name='Hudbay Minerals' with 2 new rows.
# Processed idx=251, Name='Hudson Boatworks' with 2 new rows.
# Processed idx=252, Name='Hudson's Bay Company' with 2 new rows.
# Skipping index=253, Name='Husky Energy' - no valid variants.
# Processed idx=254, Name='Hydro One' with 2 new rows.
# Skipping index=255, Name='Hydro-Québec' - no valid variants.
# Processed idx=256, Name='IGM Financial' with 2 new rows.
# Processed idx=257, Name='IL Therapeutics' with 2 new rows.
# Processed idx=258, Name='IMAX Corporation' with 2 new rows.
# Processed idx=259, Name='ImmersiVision' with 2 new rows.
# Processed idx=260, Name='Imperial Oil' with 2 new rows.
# Processed idx=261, Name='Indigo Books and Music' with 2 new rows.
# Processed idx=262, Name='Information Services Corporation' with 2 new rows.
# Skipping index=263, Name='Ingle International' - no valid variants.
# Processed idx=264, Name='Innovation Place Research Park' with 2 new rows.
# Processed idx=265, Name='Intelligent Creatures' with 2 new rows.
# Processed idx=266, Name='Inter Pipeline' with 2 new rows.
# Processed idx=267, Name='International Road Dynamics' with 2 new rows.
# Processed idx=268, Name='Intertape Polymer Group' with 2 new rows.
# Processed idx=269, Name='Investment Saskatchewan' with 2 new rows.
# Processed idx=270, Name='Ironclad Games' with 2 new rows.
# Processed idx=271, Name='Irving Oil' with 2 new rows.
# Processed idx=272, Name='Island Timberlands' with 2 new rows.
# Processed idx=273, Name='Jackson Grills' with 2 new rows.
# Processed idx=274, Name='Jazz' with 2 new rows.
# Skipping index=275, Name='J.D. Irving' - no valid variants.
# Processed idx=276, Name='Jean Coutu Group' with 2 new rows.
# Processed idx=277, Name='Jim Pattison Group' with 2 new rows.
# Skipping index=278, Name='Joker's Closet' - no valid variants.
# Processed idx=279, Name='K+S Windsor Salt' with 2 new rows.
# Processed idx=280, Name='Kal Tire' with 2 new rows.
# Processed idx=281, Name='Katz Group of Companies' with 2 new rows.
# Processed idx=282, Name='KF Aerospace' with 2 new rows.
# Processed idx=283, Name='KF Cargo' with 2 new rows.
# Processed idx=284, Name='Kinaxis' with 2 new rows.
# Processed idx=285, Name='Kinross Gold' with 2 new rows.
# Processed idx=286, Name='Kitchen Craft' with 2 new rows.
# Processed idx=287, Name='KMS Tools' with 2 new rows.
# Processed idx=288, Name='Knowledge Network' with 2 new rows.
# Processed idx=289, Name='Kobo Inc.' with 2 new rows.
# Processed idx=290, Name='Koingo Software' with 2 new rows.
# Processed idx=291, Name='Kootenay Direct Airlines' with 2 new rows.
# Processed idx=292, Name='Kruger Inc.' with 2 new rows.
# Processed idx=293, Name='L'Oie de Cravan' with 2 new rows.
# Processed idx=294, Name='La Capitale' with 2 new rows.
# Processed idx=295, Name='La Maison Simons' with 2 new rows.
# Processed idx=296, Name='Labatt Brewing Company' with 2 new rows.
# Processed idx=297, Name='LASIK MD' with 2 new rows.
# Processed idx=298, Name='Lassonde Industries' with 2 new rows.
# Processed idx=299, Name='Laurentian Bank of Canada' with 2 new rows.
# Processed idx=300, Name='Le Château' with 2 new rows.
# Processed idx=301, Name='Lee Valley Tools' with 2 new rows.
# Skipping index=302, Name='Léger Marketing' - no valid variants.
# Processed idx=303, Name='Leon's' with 2 new rows.
# Processed idx=304, Name='Linamar' with 2 new rows.
# Processed idx=305, Name='Lise Watier' with 2 new rows.
# Processed idx=306, Name='Livingston International' with 2 new rows.
# Processed idx=307, Name='Loblaw Companies' with 2 new rows.
# Processed idx=308, Name='London Drugs' with 2 new rows.
# Processed idx=309, Name='London Life Insurance Company' with 2 new rows.
# Processed idx=310, Name='Look Communications' with 2 new rows.
# Processed idx=311, Name='Lululemon Athletica' with 2 new rows.
# Processed idx=312, Name='LW Stores' with 2 new rows.
# Processed idx=313, Name='Lystek' with 2 new rows.
# Processed idx=314, Name='MacDonald, Dettwiler and Associates' with 2 new rows.
# Processed idx=315, Name='Mac's Convenience Stores' with 2 new rows.
# Processed idx=316, Name='Magna International' with 2 new rows.
# Skipping index=317, Name='Manitoba Hydro' - no valid variants.
# Processed idx=318, Name='Manitoba Liquor & Lotteries Corporation' with 2 new rows.
# Processed idx=319, Name='Manitoba Liquor Control Commission' with 2 new rows.
# Processed idx=320, Name='Manitoba Lotteries Corporation' with 2 new rows.
# Skipping index=321, Name='Manitoba Public Insurance' - no valid variants.
# Processed idx=322, Name='Manulife' with 2 new rows.
# Processed idx=323, Name='Maple Leaf Foods' with 2 new rows.
# Processed idx=324, Name='Maple Leaf Sports & Entertainment' with 2 new rows.
# Processed idx=325, Name='Maritime Life' with 2 new rows.
# Processed idx=326, Name='Mark's' with 2 new rows.
# Processed idx=327, Name='Mary Brown's' with 2 new rows.
# Skipping index=328, Name='Matrox' - no valid variants.
# Processed idx=329, Name='Maxim Power' with 2 new rows.
# Skipping index=330, Name='McCain Foods' - no valid variants.
# Processed idx=331, Name='McClelland & Stewart' with 2 new rows.
# Skipping index=332, Name='McDonald's Canada' - no valid variants.
# Processed idx=333, Name='Metal Supermarkets' with 2 new rows.
# Processed idx=334, Name='Metro Inc.' with 2 new rows.
# Processed idx=335, Name='Mitel' with 2 new rows.
# Processed idx=336, Name='MNP LLP' with 2 new rows.
# Processed idx=337, Name='Mobilicity' with 2 new rows.
# Skipping index=338, Name='Molson Brewery' - no valid variants.
# Processed idx=339, Name='Montana's BBQ & Bar' with 2 new rows.
# Processed idx=340, Name='Moosehead Breweries' with 2 new rows.
# Processed idx=341, Name='Motor Coach Industries' with 2 new rows.
# Processed idx=342, Name='Mozilla Messaging' with 2 new rows.
# Processed idx=343, Name='Mr. Sub' with 2 new rows.
# Skipping index=344, Name='Multiwebcast' - no valid variants.
# Processed idx=345, Name='National Bank of Canada' with 2 new rows.
# Processed idx=346, Name='Natura Market' with 2 new rows.
# Processed idx=347, Name='Nature's Path' with 2 new rows.
# Processed idx=348, Name='NCIX' with 2 new rows.
# Processed idx=349, Name='Nelvana' with 2 new rows.
# Processed idx=350, Name='New Flyer Industries' with 2 new rows.
# Processed idx=351, Name='New York Fries' with 2 new rows.
# Processed idx=352, Name='Nexen' with 2 new rows.
# Processed idx=353, Name='Nexient Learning' with 2 new rows.
# Processed idx=354, Name='Nordion' with 2 new rows.
# Processed idx=355, Name='Nortel' with 2 new rows.
# Processed idx=356, Name='North West Company' with 2 new rows.
# Processed idx=357, Name='Nova Chemicals' with 2 new rows.
# Skipping index=358, Name='Nova Scotia Power' - no valid variants.
# Processed idx=359, Name='Novacam Technologies' with 2 new rows.
# Processed idx=360, Name='Novosbed' with 2 new rows.
# Processed idx=361, Name='Nuu-chah-nulth Economic Development Corporation' with 2 new rows.
# Skipping index=362, Name='Ocean Productions' - no valid variants.
# Processed idx=363, Name='Oland Brewery' with 2 new rows.
# Processed idx=364, Name='Omineca Cablevision' with 2 new rows.
# Processed idx=365, Name='Onex Corporation' with 2 new rows.
# Processed idx=366, Name='Ontario Lottery and Gaming Corporation' with 2 new rows.
# Processed idx=367, Name='OpenText' with 2 new rows.
# Processed idx=368, Name='Osisko Mining' with 2 new rows.
# Skipping index=369, Name='Ossian Studios' - no valid variants.
# Processed idx=370, Name='Pacific & Western Bank of Canada' with 2 new rows.
# Processed idx=371, Name='Pacific Coastal Airlines' with 2 new rows.
# Processed idx=372, Name='Packers Plus Energy Services' with 2 new rows.
# Processed idx=373, Name='PainCeptor Pharma' with 2 new rows.
# Processed idx=374, Name='Palliser Furniture' with 2 new rows.
# Processed idx=375, Name='Pan American Silver' with 2 new rows.
# Processed idx=376, Name='Panago' with 2 new rows.
# Processed idx=377, Name='Paramount Resources' with 2 new rows.
# Processed idx=378, Name='Parmalat Canada' with 2 new rows.
# Skipping index=379, Name='Parrish & Heimbecker' - no valid variants.
# Processed idx=380, Name='Pascan Aviation' with 2 new rows.
# Processed idx=381, Name='Paterson GlobalFoods' with 2 new rows.
# Processed idx=382, Name='Persona Communications' with 2 new rows.
# Processed idx=383, Name='Petcetera' with 2 new rows.
# Processed idx=384, Name='Petro-Canada' with 2 new rows.
# Processed idx=385, Name='Pharmasave' with 2 new rows.
# Processed idx=386, Name='Pharmascience' with 2 new rows.
# Processed idx=387, Name='Pizza Nova' with 2 new rows.
# Processed idx=388, Name='Pizza Pizza' with 2 new rows.
# Processed idx=389, Name='Pollard Banknote' with 2 new rows.
# Processed idx=390, Name='Porter Airlines' with 2 new rows.
# Processed idx=391, Name='PotashCorp' with 2 new rows.
# Processed idx=392, Name='Power Corporation of Canada' with 2 new rows.
# Processed idx=393, Name='Prairie Plant Systems' with 2 new rows.
# Processed idx=394, Name='Pratt & Whitney Canada' with 2 new rows.
# Processed idx=395, Name='Precision Drilling' with 2 new rows.
# Skipping index=396, Name='Premium Brands Holdings Corporation' - no valid variants.
# Processed idx=397, Name='Prevost Car' with 2 new rows.
# Processed idx=398, Name='Priszm' with 2 new rows.
# Processed idx=399, Name='Pronto Airways' with 2 new rows.
# Processed idx=400, Name='Protecode' with 2 new rows.
# Processed idx=401, Name='PsyMontréal' with 2 new rows.
# Processed idx=402, Name='Pultronics' with 2 new rows.
# Processed idx=403, Name='Purolator Courier' with 2 new rows.
# Processed idx=404, Name='Quebecor' with 2 new rows.
# Processed idx=405, Name='Quester Tangent Corporation' with 2 new rows.
# Processed idx=406, Name='Recipe Unlimited' with 2 new rows.
# Processed idx=407, Name='Red Back Mining' with 2 new rows.
# Processed idx=408, Name='Red Barrels' with 2 new rows.
# Processed idx=409, Name='Regional Maple Leaf Communications' with 2 new rows.
# Processed idx=410, Name='Reimer Express Lines' with 2 new rows.
# Processed idx=411, Name='Resolute Forest Products' with 2 new rows.
# Processed idx=412, Name='Rhino Media Group' with 2 new rows.
# Processed idx=413, Name='Richardson International' with 2 new rows.
# Processed idx=414, Name='Rockstar Toronto' with 2 new rows.
# Processed idx=415, Name='Rockstar Vancouver' with 2 new rows.
# Processed idx=416, Name='Rogers Communications' with 2 new rows.
# Processed idx=417, Name='Rona Inc.' with 2 new rows.
# Processed idx=418, Name='Roots Canada' with 2 new rows.
# Processed idx=419, Name='Royal Bank of Canada' with 2 new rows.
# Processed idx=420, Name='Royal LePage' with 2 new rows.
# Processed idx=421, Name='Samuel, Son & Co.' with 2 new rows.
# Skipping index=422, Name='Sandman Hotels' - no valid variants.
# Processed idx=423, Name='Sandvine' with 2 new rows.
# Processed idx=424, Name='Saputo Inc.' with 2 new rows.
# Processed idx=425, Name='Saskatchewan Government Insurance' with 2 new rows.
# Processed idx=426, Name='Saskatchewan Minerals' with 2 new rows.
# Processed idx=427, Name='SRC' with 2 new rows.
# Processed idx=428, Name='SaskPower' with 2 new rows.
# Skipping index=429, Name='SaskTel' - no valid variants.
# Processed idx=430, Name='Save-On-Foods' with 2 new rows.
# Processed idx=431, Name='Scotiabank' with 2 new rows.
# Processed idx=432, Name='Sears Canada' with 2 new rows.
# Processed idx=433, Name='Second Cup' with 2 new rows.
# Processed idx=434, Name='Sepro Mineral Systems' with 2 new rows.
# Processed idx=435, Name='Servus Credit Union' with 2 new rows.
# Processed idx=436, Name='Shaftebury Brewing Company' with 2 new rows.
# Processed idx=437, Name='Shaw Communications' with 2 new rows.
# Processed idx=438, Name='Shell Canada' with 2 new rows.
# Processed idx=439, Name='Shopify' with 2 new rows.
# Processed idx=440, Name='Shoppers Drug Mart' with 2 new rows.
# Processed idx=441, Name='Shore Tilbe Irwin + Partners' with 2 new rows.
# Processed idx=442, Name='Siemens Transportation Group' with 2 new rows.
# Skipping index=443, Name='Sierra Wireless' - no valid variants.
# Processed idx=444, Name='Sifto Canada' with 2 new rows.
# Processed idx=445, Name='SiriusXM Canada' with 2 new rows.
# Processed idx=446, Name='sisu production' with 2 new rows.
# Processed idx=447, Name='Sleeman Breweries' with 2 new rows.
# Processed idx=448, Name='Sleep Country Canada' with 2 new rows.
# Processed idx=449, Name='Smart Technologies' with 2 new rows.
# Processed idx=450, Name='SNC-Lavalin' with 2 new rows.
# Skipping index=451, Name='Sobeys' - no valid variants.
# Processed idx=452, Name='Soquelec' with 2 new rows.
# Processed idx=453, Name='Splashdot' with 2 new rows.
# Skipping index=454, Name='St Hubertus & Oak Bay Estate Winery' - no valid variants.
# Processed idx=455, Name='Stanfield's' with 2 new rows.
# Skipping index=456, Name='Stelco' - no valid variants.
# Processed idx=457, Name='Sun Life Financial' with 2 new rows.
# Processed idx=458, Name='Suncor Energy' with 2 new rows.
# Processed idx=459, Name='Sun-Rype' with 2 new rows.
# Processed idx=460, Name='Sunward Aerospace Group' with 2 new rows.
# Processed idx=461, Name='Swiss Chalet' with 2 new rows.
# Processed idx=462, Name='SydneyPLUS International' with 2 new rows.
# Processed idx=463, Name='Syncrude' with 2 new rows.
# Processed idx=464, Name='Synex International' with 2 new rows.
# Processed idx=465, Name='T & T Supermarket' with 2 new rows.
# Processed idx=466, Name='Tahera' with 2 new rows.
# Skipping index=467, Name='Talentvision' - no valid variants.
# Skipping index=468, Name='Talisman Energy' - no valid variants.
# Processed idx=469, Name='Tamarack Developments Corporation' with 2 new rows.
# Processed idx=470, Name='Taseko Mines' with 2 new rows.
# Processed idx=471, Name='TC Energy' with 2 new rows.
# Processed idx=472, Name='Teck Resources' with 2 new rows.
# Processed idx=473, Name='Teledyne DALSA' with 2 new rows.
# Processed idx=474, Name='Telesat' with 2 new rows.
# Processed idx=475, Name='Telus' with 2 new rows.
# Processed idx=476, Name='Tembec' with 2 new rows.
# Processed idx=477, Name='The Bargain! Shop' with 2 new rows.
# Processed idx=478, Name='The Brick' with 2 new rows.
# Processed idx=479, Name='The Embassy Visual Effects' with 2 new rows.
# Processed idx=480, Name='The Globe and Mail' with 2 new rows.
# Skipping index=481, Name='The Insurance Company of Prince Edward Island' - no valid variants.
# Processed idx=482, Name='The Source' with 2 new rows.
# Processed idx=483, Name='Timothy's World Coffee' with 2 new rows.
# Processed idx=484, Name='TM4' with 2 new rows.
# Processed idx=485, Name='TMX Group' with 2 new rows.
# Skipping index=486, Name='Tolko' - no valid variants.
# Processed idx=487, Name='Toronto Stock Exchange' with 2 new rows.
# Processed idx=488, Name='Toronto-Dominion Bank' with 2 new rows.
# Processed idx=489, Name='Torstar' with 2 new rows.
# Processed idx=490, Name='TransAlta' with 2 new rows.
# Processed idx=491, Name='TransGas' with 2 new rows.
# Processed idx=492, Name='Transwest Air' with 2 new rows.
# Processed idx=493, Name='Treehouse TV' with 2 new rows.
# Processed idx=494, Name='Tridel' with 2 new rows.
# Processed idx=495, Name='Triple Five Group' with 2 new rows.
# Processed idx=496, Name='Ubisoft Montreal' with 2 new rows.
# Processed idx=497, Name='Ubisoft Toronto' with 2 new rows.
# Processed idx=498, Name='Ultramar' with 2 new rows.
# Processed idx=499, Name='Umbra' with 2 new rows.
# Skipping index=500, Name='United Furniture Warehouse' - no valid variants.
# Processed idx=501, Name='Vachon Bakery' with 2 new rows.
# Processed idx=502, Name='Vancity' with 2 new rows.
# Processed idx=503, Name='Vancity Community Investment Bank' with 2 new rows.
# Processed idx=504, Name='Via Rail' with 2 new rows.
# Processed idx=505, Name='Vidéotron' with 2 new rows.
# Processed idx=506, Name='Virtual Brokers' with 2 new rows.
# Processed idx=507, Name='Vista Broadcast Group' with 2 new rows.
# Processed idx=508, Name='Vortex Aquatic Structures International' with 2 new rows.
# Processed idx=509, Name='Wardrop Engineering Inc.' with 2 new rows.
# Processed idx=510, Name='Waterloo Maple Inc.' with 2 new rows.
# Processed idx=511, Name='Wawanesa Insurance' with 2 new rows.
# Processed idx=512, Name='West Fraser Timber' with 2 new rows.
# Processed idx=513, Name='West Wind Aviation' with 2 new rows.
# Processed idx=514, Name='WestJet' with 2 new rows.
# Processed idx=515, Name='WingTips Airport Services' with 2 new rows.
# Processed idx=516, Name='Winners' with 2 new rows.
# Processed idx=517, Name='Yara Belle Plaine' with 2 new rows.
# Processed idx=518, Name='Yogen Früz' with 2 new rows.
# Processed idx=519, Name='Z8Games' with 2 new rows.
# Processed idx=520, Name='Zag Bank' with 2 new rows.
# Processed idx=521, Name='Zellers' with 2 new rows.
# Processed idx=522, Name='ZENN Motor Company' with 2 new rows.
#
# Final dataset size: 934 rows.

# %%
final_df
# Out:
#      CompanyID                          Name           Industry  \
# 0            0               1-800-GOT-JUNK?        Industrials
# 1            0               1-800-GOT-JUNK?        Industrials
# 2            1                   Norda Stelo        Industrials
# 3            1                   Norda Stelo        Industrials
# 4            2  3Way International Logistics        Industrials
# ..         ...                           ...                ...
# 929        520                      Zag Bank         Financials
# 930        521                       Zellers  Consumer services
# 931        521                       Zellers  Consumer services
# 932        522            ZENN Motor Company     Consumer goods
# 933        522            ZENN Motor Company     Consumer goods
#
#                         Sector                      Notes Headquarters  \
# 0    Waste & disposal services               Junk removal    Vancouver
# 1    Waste & disposal services               Junk removal    Vancouver
# 2     Construction & Materials        Integrated projects  Quebec City
# 3     Construction & Materials        Integrated projects  Quebec City
# 4    Business support services         Freight forwarding  Mississauga
# ..                         ...                        ...          ...
# 929                      Banks                       Bank      Calgary
# 930         Broadline retailer  Acquired by Target Canada     Brampton
# 931         Broadline retailer  Acquired by Target Canada     Brampton
# 932                Automobiles          Electric vehicles     Montreal
# 933                Automobiles          Electric vehicles     Montreal
#
#                          Name_One                                 Name_Two  \
# 0                 1-800-GOT-JUNK?  RBDS Rubbish Boys Disposal Service Inc.
# 1                 1-800-GOT-JUNK?                     1-800-JUNK-PROS Ltd.
# 2                     Norda Stelo                             GENIVAR Inc.
# 3                     Norda Stelo                             Noranda Inc.
# 4    3Way International Logistics          Three-Way Int'l Logistics Corp.
# ..                            ...                                      ...
# 929                      Zag Bank                                 B2B Bank
# 930                       Zellers   Hudson's Bay Trading Company (Zellers)
# 931                       Zellers           Zellweger Analytics Canada Ltd
# 932            ZENN Motor Company                     Feel Good Cars, Inc.
# 933            ZENN Motor Company                         Zen Motors Group
#
#      Label
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1
# ..     ...
# 929      0
# 930      1
# 931      0
# 932      1
# 933      0
#
# [934 rows x 9 columns]

# %%
##################################
# 4. Save to CSV (no GPT traces) #
##################################
output_file = "canadian_company_variants.csv"
final_df.to_csv(output_file, index=False)

print(f"Saved final dataset to '{output_file}'.")
# Out:
# Saved final dataset to 'canadian_company_variants.csv'.
